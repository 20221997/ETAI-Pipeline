# %%
#all the functions that you need to call and run that we defined in our source - main.py
#requirements - versions and libraries that you need in on line of code 
#change the atributtes
#ignore certain things in our folders - gitignore
#README - where we put and explain the changes that we did im the code.
#one source code for each methid of the ML project.
#to see if it's overfitting, we look to the the gap to see if there is overfitting or not (look to evaluate)
# COMPAS - algorithm from united states 

#For this semester - We will work on a case 
# build a model, trying to see if the model is being biased or not 
# copy the repository to your account - fork
